# %%
# !curl --data "cols=active,alert,aroused,sleepy,tired,drowsy,anxious,jittery,nervous,calm,relaxed,at_ease&type=cor" http://localhost:6000/score
# Out:
# [{"EA":1,"TA":0.1174,"EAp":0.718,"EAn":-0.5441,"TAp":0.2627,"TAn":0.1142,"_row":"EA"},{"EA":0.1174,"TA":1,"EAp":0.1369,"EAn":-0.0004,"TAp":0.606,"TAn":-0.6262,"_row":"TA"},{"EA":0.718,"TA":0.1369,"EAp":1,"EAn":0.1934,"TAp":0.512,"TAn":0.3347,"_row":"EAp"},{"EA":-0.5441,"TA":-0.0004,"EAp":0.1934,"EAn":1,"TAp":0.2468,"TAn":0.2425,"_row":"EAn"},{"EA":0.2627,"TA":0.606,"EAp":0.512,"EAn":0.2468,"TAp":1,"TAn":0.2407,"_row":"TAp"},{"EA":0.1142,"TA":-0.6262,"EAp":0.3347,"EAn":0.2425,"TAp":0.2407,"TAn":1,"_row":"TAn"}]

# %%
# !curl --data "nr=1000" http://localhost:6000/predict
# Out:
# {"error":["404 - Resource Not Found"]}

# %%
# !curl --data "nr=1000" http://localhost:6060/score
# Out:
# [{"IRD_NUMBER":71596281,"RETURN_PERIOD_DATE":"2015-03-31","RETURN_TYPE":"IR6","LOCATION_NUMBER":1,"TAX_TYPE":"INC","FILING_FREQUENCY":1,"POPULATION_NO":1,"EST_OTHER_INCOME":-390.0537,"PROB_NIL_OTHER_INCOME":0.48,"EST_RESIDUAL_INCOME_TAX":-110.1218,"PROB_NIL_RESIDUAL_INCOME_TAX":0.49,"PROB_RIT_LESS_200":0.57,"PROB_OTHER_INC_LESS_1000":0.52,"PROB_NIL_INC_ALLOCN_TO_BNFICIR":0.51},{"IRD_NUMBER":98191879,"RETURN_PERIOD_DATE":"2015-03-31","RETURN_TYPE":"IR6","LOCATION_NUMBER":1,"TAX_TYPE":"INC","FILING_FREQUENCY":1,"POPULATION_NO":1,"EST_OTHER_INCOME":1414.2249,"PROB_NIL_OTHER_INCOME":0.56,"EST_RESIDUAL_INCOME_TAX":-496.9347,"PROB_NIL_RESIDUAL_INCOME_TAX":0.63,"PROB_RIT_LESS_200":0.65,"PROB_OTHER_INC_LESS_1000":0.57,"PROB_NIL_INC_ALLOCN_TO_BNFICIR":0.53},{"IRD_NUMBER":60936331,"RETURN_PERIOD_DATE":"2015-03-31","RETURN_TYPE":"IR6","LOCATION_NUMBER":1,"TAX_TYPE":"INC","FILING_FREQUENCY":1,"POPULATION_NO":1,"EST_OTHER_INCOME":-1454.7315,"PROB_NIL_OTHER_INCOME":0.52,"EST_RESIDUAL_INCOME_TAX":-
# ...

# %%
# !docker logs score
# Out:
# [!p>
# Testing for cluster user account...
#
# (BEnter MapR cluster user name: mapr
#
# User 'mapr' does not exist. Creating new cluster user account...
#
# Enter 'mapr' uid: 5000
#  Enter 'mapr' group name: users
#  Enter 'mapr' password: mapr
#  ...Success
#
# Configuring MapR client ( -c -C mapr-1,mapr-2,mapr-3 -N maprlab)...
#
# create /opt/mapr/conf/conf.old
# Configuring Hadoop-2.7.0 at /opt/mapr/hadoop/hadoop-2.7.0
# Done configuring Hadoop
# CLDB node list: mapr-1:7222,mapr-2:7222,mapr-3:7222
# Zookeeper node list:
#
# ...Success
#
# 2017-11-27 06:14:43,570 INFO supervisord started with pid 935
# 2017-11-27 06:14:44,572 INFO spawned: 'program_exit' with pid 938
# 2017-11-27 06:14:44,574 INFO spawned: 'plumber' with pid 939
# 2017-11-27 06:14:46,486 INFO success: program_exit entered RUNNING state, process has stayed up for > than 1 seconds (startsecs)
# 2017-11-27 06:14:50,491 INFO success: plumber entered RUNNING state, process has stayed up for > than 5 seconds (startsecs)

# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE               COMMAND                  CREATED             STATUS                     PORTS                    NAMES
# 6e9fc2afc519        thbeh/test          "/opt/mapr/install..."   3 minutes ago       Up 3 minutes               0.0.0.0:6000->8000/tcp   naughty_stallman
# 466d582c7c5b        thbeh/test          "/opt/mapr/install..."   9 minutes ago       Exited (0) 3 minutes ago                            upbeat_carson

# %%
# !docker push thbeh/test
# Out:
# 6e9fc2afc519

# %%
# !cat r-base/Dockerfile
# Out:
# cat: r-base/Dockerfile: No such file or directory

# %%
# !cat /poc/AZ/notebook/Beh/ACS-Deployment-Score/flaskwebapp/rbase/Dockerfile
# Out:
# ## Emacs, make this -*- mode: sh; -*-
#
# ## FROM ubuntu:xenial
# FROM thbeh/pacc:5.2.2_3.0.1_ubuntu16_yarn_fuse_spark_streams
#
# ## This handle reaches Carl and Dirk
# ## MAINTAINER "Carl Boettiger and Dirk Eddelbuettel" rocker-maintainers@eddelbuettel.com
#
# ## Set a default user. Available via runtime flag `--user docker`
# ## Add user to 'staff' group, granting them write privileges to /usr/local/lib/R/site.library
# ## User should also have & own a home directory (for rstudio or linked volumes to work properly).
# RUN useradd docker \
# 	&& mkdir /home/docker \
# 	&& chown docker:docker /home/docker \
# 	&& addgroup docker staff
#
# RUN apt-get update \
# 	&& apt-get install -y --no-install-recommends \
# 		software-properties-common \
#                 ed \
# 		less \
# 		locales \
# 		vim-tiny \
# 		wget \
# 		ca-certificates \
#                 git-core \
#                 libssl-dev \
#                 libcurl4-openssl-dev \
#                 default-jdk \
# ...

# %%
# !cat /poc/AZ/notebook/Beh/ACS-Deployment-Score/flaskwebapp/rbase/requirements.R
# Out:
# install.packages(c("devtools"), repos="http://cran.us.r-project.org", dependencies=TRUE)
