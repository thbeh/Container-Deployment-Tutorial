# %%
# !docker version

# %%
# !mkdir flaskwebapp
# !mkdir flaskwebapp/code
# !mkdir flaskwebapp/etc
# Out:
# mkdir: cannot create directory ‘flaskwebapp’: File exists
# mkdir: cannot create directory ‘flaskwebapp/code’: File exists
# mkdir: cannot create directory ‘flaskwebapp/etc’: File exists

# %%
import os
from os import path
import json 

image_name = "thbeh/test"
application_path = 'flaskwebapp'
docker_file_location = path.join(application_path, 'Dockerfile')

# %%
# %%writefile flaskwebapp/packages.R
# install.packages(c("psych",
#                    "jsonlite",
#                    "sergeant",
#                    "randomForest",
#                    "foreach",
#                    "iterators",
#                    "parallel",
#                    "doParallel",
#                    "knitr",
#                    "stats",
#                    "rmarkdown",
#                    "ROCR",
#                    "gridExtra",
#                    "ggplot2"
#                   ),
# repos = "http://cran.us.r-project.org", dependencies = TRUE)
#
# ## install.packages("/poc/AZ/Kate/returnsModel_2.1-6.tar.gz", repos = NULL, type = "source")
# Out:
# Overwriting flaskwebapp/packages.R

# %%
# %%writefile flaskwebapp/code/scoreDrill.R
#
# suppressMessages(library(psych))
# suppressMessages(library(jsonlite))
# suppressMessages(library(sergeant))
# suppressMessages(library(returnsModel))
#
# options(warn = -1)
#
# #* @post /score
# runModel <- function(nr) {
#     RunModellingAndScoring(model="OR", returnName="IR6", projectStage="TEST", nrows=nr)
# }
#
# #* @post /sum
# addTwo <- function(a ,b) {
#     as.numeric(a) + as.numeric(b)
# }
# Out:
# Overwriting flaskwebapp/code/scoreDrill.R

# %%
# %%writefile flaskwebapp/etc/supervisord.conf
# [supervisord]
# logfile=/tmp/supervisord.log ; (main log file;default $CWD/supervisord.log)
# logfile_maxbytes=50MB        ; (max main logfile bytes b4 rotation;default 50MB)
# logfile_backups=10           ; (num of main logfile rotation backups;default 10)
# loglevel=info                ; (log level;default info; others: debug,warn,trace)
# pidfile=/tmp/supervisord.pid ; (supervisord pidfile;default supervisord.pid)
# nodaemon=true               ; (start in foreground if true;default false)
# minfds=1024                  ; (min. avail startup file descriptors;default 1024)
# minprocs=200                 ; (min. avail process descriptors;default 200)
#
# [program:plumber]
# command=/usr/bin/Rscript -e "pr <- plumber::plumb('/tmp/scoreDrill.R'); pr$run(host='0.0.0.0', port=8080)"
# startretries=2
# startsecs=5
# priority=3
#
# [eventlistener:program_exit]
# command=python kill_supervisor.py
# directory=/code
# events=PROCESS_STATE_FATAL
# priority=2
# Out:
# Overwriting flaskwebapp/etc/supervisord.conf

# %%
# %%writefile flaskwebapp/Dockerfile
# FROM thbeh/r-base:3.4.2
#
# RUN apt-get update && apt-get install -y supervisor libxml2-dev
#
# COPY packages.R /tmp/
# COPY scoreDrill.R /tmp/
#
# RUN mkdir /code
# ADD code /code
# ADD etc /etc
#
# RUN Rscript /tmp/packages.R
# RUN R CMD INSTALL /code/returnsModel_2.1-6.tar.gz
#
# EXPOSE 8080
# CMD ["supervisord","-c", "/etc/supervisord.conf"]
# Out:
# Overwriting flaskwebapp/Dockerfile

# %%
# !ls -l flaskwebapp/code
# Out:
# total 157
# -rwxrwxrwx 1 user00 user00    885 Nov 26 20:36 kill_supervisor.py
# -rw-r--r-- 1 user00 user00 159017 Nov 27 03:50 returnsModel_2.1-6.tar.gz
# -rwxrwxrwx 1 user00 user00    138 Nov 27 03:46 scoreDrill.R

# %%
# !docker build -t $image_name -f $docker_file_location $application_path --no-cache
# Out:
# Sending build context to Docker daemon 177.7 kB
# Step 1/11 : FROM thbeh/r-base:3.4.2
#  ---> 64cb364c592f
# Step 2/11 : RUN apt-get update && apt-get install -y supervisor libxml2-dev
#  ---> Running in bacc08e9ff28
# Get:1 http://security.ubuntu.com/ubuntu xenial-security InRelease [102 kB]
# Ign:2 http://package.mapr.com/releases/v5.2.2/ubuntu binary InRelease
# Get:3 http://ppa.launchpad.net/marutter/c2d4u/ubuntu xenial InRelease [17.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu xenial InRelease [247 kB]
# Ign:5 http://package.mapr.com/releases/MEP/MEP-3.0.1/ubuntu binary InRelease
# Get:6 http://package.mapr.com/releases/v5.2.2/ubuntu binary Release [2,728 B]
# Get:7 http://package.mapr.com/releases/MEP/MEP-3.0.1/ubuntu binary Release [2,728 B]
# Get:8 http://package.mapr.com/releases/v5.2.2/ubuntu binary Release.gpg [475 B]
# Get:9 http://package.mapr.com/releases/MEP/MEP-3.0.1/ubuntu binary Release.gpg [475 B]
# Get:10 http://package.mapr.com/releases/v5.2.2/ubuntu binary/trusty amd64 Packages [3,249 B]
# Get:11 http://package.mapr.com/releases/MEP/MEP-3.0.1/ubuntu binary/trusty amd64 Packages [10.8 kB]
# Get:12 http://ppa.launchpad.net/marutter/rrutter/ubuntu xenial InRelease [17.5 kB]
# Get:13 http://security.ubuntu.com/ubuntu xenial-security/universe Sources [53.1 kB]
# Get:14 http://security.ubuntu.com/ubuntu xenial-security/main amd64 Packages [504 kB]
# Get:15 http://archive.ubuntu.com/ubuntu xenial-updates InRelease [102 kB]
# Get:16 http://security.ubuntu.com/ubuntu xenial-security/restricted amd64 Packages [12.9 kB]
# Get:17 http://security.ubuntu.com/ubuntu xenial-security/universe amd64 Packages [229 kB]
# Get:18 http://archive.ubuntu.com/ubuntu xenial-backports InRelease [102 kB]
# Get:19 http://ppa.launchpad.net/marutter/c2d4u/ubuntu xenial/main Sources [1,277 kB]
# Get:20 http://security.ubuntu.com/ubuntu xenial-security/multiverse amd64 Packages [3,479 B]
# Get:21 http://archive.ubuntu.com/ubuntu xenial/universe Sources [9,802 kB]
# Get:22 http://archive.ubuntu.com/ubuntu xenial/main amd64 Packages [1,558 kB]
# Get:23 http://archive.ubuntu.com/ubuntu xenial/restricted amd64 Packages [14.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu xenial/universe amd64 Packages [9,827 kB]
# Get:25 http://ppa.launchpad.net/marutter/c2d4u/ubuntu xenial/main amd64 Packages [666 kB]
# Get:26 http://archive.ubuntu.com/ubuntu xenial/multiverse amd64 Packages [176 kB]
# Get:27 http://archive.ubuntu.com/ubuntu xenial-updates/universe Sources [228 kB]
# Get:28 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 Packages [864 kB]
# Get:29 http://archive.ubuntu.com/ubuntu xenial-updates/restricted amd64 Packages [13.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu xenial-updates/universe amd64 Packages [711 kB]
# Get:31 http://archive.ubuntu.com/ubuntu xenial-updates/multiverse amd64 Packages [18.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu xenial-backports/main amd64 Packages [5,174 B]
# Get:33 http://archive.ubuntu.com/ubuntu xenial-backports/universe amd64 Packages [7,135 B]
# Get:34 http://ppa.launchpad.net/marutter/rrutter/ubuntu xenial/main Sources [10.8 kB]
# Get:35 http://ppa.launchpad.net/marutter/rrutter/ubuntu xenial/main amd64 Packages [8,639 B]
# Fetched 26.6 MB in 12s (2,062 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   python-meld3
# Suggested packages:
#   supervisor-doc
# The following NEW packages will be installed:
#   libxml2-dev python-meld3 supervisor
# 0 upgraded, 3 newly installed, 0 to remove and 2 not upgraded.
# Need to get 1,028 kB of archives.
# After this operation, 5,068 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 libxml2-dev amd64 2.9.3+dfsg1-1ubuntu0.3 [744 kB]
# Get:2 http://archive.ubuntu.com/ubuntu xenial/universe amd64 python-meld3 all 1.0.2-2 [30.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu xenial-updates/universe amd64 supervisor all 3.2.0-2ubuntu0.1 [253 kB]
# debconf: unable to initialize frontend: Dialog
# debconf: (TERM is not set, so the dialog frontend is not usable.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 1,028 kB in 2s (391 kB/s)
# Selecting previously unselected package libxml2-dev:amd64.
# (Reading database ... 27237 files and directories currently installed.)
# Preparing to unpack .../libxml2-dev_2.9.3+dfsg1-1ubuntu0.3_amd64.deb ...
# Unpacking libxml2-dev:amd64 (2.9.3+dfsg1-1ubuntu0.3) ...
# Selecting previously unselected package python-meld3.
# Preparing to unpack .../python-meld3_1.0.2-2_all.deb ...
# Unpacking python-meld3 (1.0.2-2) ...
# Selecting previously unselected package supervisor.
# Preparing to unpack .../supervisor_3.2.0-2ubuntu0.1_all.deb ...
# Unpacking supervisor (3.2.0-2ubuntu0.1) ...
# Processing triggers for man-db (2.7.5-1) ...
# Processing triggers for systemd (229-4ubuntu21) ...
# Setting up libxml2-dev:amd64 (2.9.3+dfsg1-1ubuntu0.3) ...
# Setting up python-meld3 (1.0.2-2) ...
# Setting up supervisor (3.2.0-2ubuntu0.1) ...
# insserv: warning: script 'mapr-fuse' missing LSB tags and overrides
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Processing triggers for systemd (229-4ubuntu21) ...
#  ---> 45e82578cacb
# Removing intermediate container bacc08e9ff28
# Step 3/11 : COPY packages.R /tmp/
#  ---> 9eea213ee3dc
# Removing intermediate container f7766b3f7b29
# Step 4/11 : COPY scoreDrill.R /tmp/
#  ---> af7da78908af
# Removing intermediate container 23ac164dd93b
# Step 5/11 : RUN mkdir /code
#  ---> Running in fae2d9863ae8
#  ---> d6e96c76fe77
# Removing intermediate container fae2d9863ae8
# Step 6/11 : ADD code /code
#  ---> 9ded3a3d28fe
# Removing intermediate container 50fefb8d3dfc
# Step 7/11 : ADD etc /etc
#  ---> 40e6fbbaa9e6
# Removing intermediate container 5b77645e0388
# Step 8/11 : RUN Rscript /tmp/packages.R
#  ---> Running in 17a857eef7cf
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# Warning: dependencies ‘graph’, ‘Rgraphviz’ are not available
# also installing the dependencies ‘lava’, ‘kernlab’, ‘CVST’, ‘DEoptimR’, ‘abind’, ‘coda’, ‘tidyr’, ‘prodlim’, ‘DRR’, ‘robustbase’, ‘sfsmisc’, ‘arm’, ‘bindr’, ‘colorspace’, ‘broom’, ‘ipred’, ‘dimRed’, ‘lubridate’, ‘timeDate’, ‘ddalpha’, ‘gower’, ‘RcppRoll’, ‘tidyselect’, ‘checkmate’, ‘zoo’, ‘pbivnorm’, ‘quadprog’, ‘numDeriv’, ‘matrixcalc’, ‘mi’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘R.methodsS3’, ‘R.oo’, ‘R.utils’, ‘R.cache’, ‘bindrcpp’, ‘glue’, ‘rlang’, ‘plogr’, ‘hms’, ‘dichromat’, ‘munsell’, ‘labeling’, ‘viridisLite’, ‘ModelMetrics’, ‘recipes’, ‘filehash’, ‘xtable’, ‘sourcetools’, ‘gtools’, ‘gdata’, ‘caTools’, ‘Formula’, ‘latticeExtra’, ‘acepack’, ‘data.table’, ‘htmlTable’, ‘viridis’, ‘mvtnorm’, ‘TH.data’, ‘sandwich’, ‘SparseM’, ‘MatrixModels’, ‘gdtools’, ‘mnormt’, ‘GPArotation’, ‘lavaan’, ‘sem’, ‘lme4’, ‘Rcsdp’, ‘plyr’, ‘R.rsp’, ‘sp’, ‘DBI’, ‘dplyr’, ‘dbplyr’, ‘readr’, ‘purrr’, ‘scales’, ‘RJDBC’, ‘rJava’, ‘RColorBrewer’, ‘RUnit’, ‘caret’, ‘mlbench’, ‘formatR’, ‘testit’, ‘rgl’, ‘htmlwidgets’, ‘webshot’, ‘tikzDevice’, ‘png’, ‘jpeg’, ‘XML’, ‘RCurl’, ‘tibble’, ‘shiny’, ‘tufte’, ‘gplots’, ‘gtable’, ‘egg’, ‘reshape2’, ‘ggplot2movies’, ‘hexbin’, ‘Hmisc’, ‘mapproj’, ‘maps’, ‘maptools’, ‘multcomp’, ‘quantreg’, ‘svglite’
#
# trying URL 'http://cran.us.r-project.org/src/contrib/lava_1.5.1.tar.gz'
# Content type 'application/x-gzip' length 842110 bytes (822 KB)
# ==================================================
# downloaded 822 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/kernlab_0.9-25.tar.gz'
# Content type 'application/x-gzip' length 1170281 bytes (1.1 MB)
# ==================================================
# downloaded 1.1 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/CVST_0.2-1.tar.gz'
# Content type 'application/x-gzip' length 12452 bytes (12 KB)
# ==================================================
# downloaded 12 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/DEoptimR_1.0-8.tar.gz'
# Content type 'application/x-gzip' length 35401 bytes (34 KB)
# ==================================================
# downloaded 34 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/abind_1.4-5.tar.gz'
# Content type 'application/x-gzip' length 21810 bytes (21 KB)
# ==================================================
# downloaded 21 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/coda_0.19-1.tar.gz'
# Content type 'application/x-gzip' length 73734 bytes (72 KB)
# ==================================================
# downloaded 72 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/tidyr_0.7.2.tar.gz'
# Content type 'application/x-gzip' length 369542 bytes (360 KB)
# ==================================================
# downloaded 360 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/prodlim_1.6.1.tar.gz'
# Content type 'application/x-gzip' length 124175 bytes (121 KB)
# ==================================================
# downloaded 121 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/DRR_0.0.2.tar.gz'
# Content type 'application/x-gzip' length 116827 bytes (114 KB)
# ==================================================
# downloaded 114 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/robustbase_0.92-8.tar.gz'
# Content type 'application/x-gzip' length 3479092 bytes (3.3 MB)
# ==================================================
# downloaded 3.3 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/sfsmisc_1.1-1.tar.gz'
# Content type 'application/x-gzip' length 168607 bytes (164 KB)
# ==================================================
# downloaded 164 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/arm_1.9-3.tar.gz'
# Content type 'application/x-gzip' length 77648 bytes (75 KB)
# ==================================================
# downloaded 75 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/bindr_0.1.tar.gz'
# Content type 'application/x-gzip' length 5928 bytes
# ==================================================
# downloaded 5928 bytes
#
# trying URL 'http://cran.us.r-project.org/src/contrib/colorspace_1.3-2.tar.gz'
# Content type 'application/x-gzip' length 293433 bytes (286 KB)
# ==================================================
# downloaded 286 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/broom_0.4.3.tar.gz'
# Content type 'application/x-gzip' length 1397648 bytes (1.3 MB)
# ==================================================
# downloaded 1.3 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/ipred_0.9-6.tar.gz'
# Content type 'application/x-gzip' length 186516 bytes (182 KB)
# ==================================================
# downloaded 182 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/dimRed_0.1.0.tar.gz'
# Content type 'application/x-gzip' length 70299 bytes (68 KB)
# ==================================================
# downloaded 68 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/lubridate_1.7.1.tar.gz'
# Content type 'application/x-gzip' length 399040 bytes (389 KB)
# ==================================================
# downloaded 389 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/timeDate_3042.101.tar.gz'
# Content type 'application/x-gzip' length 314661 bytes (307 KB)
# ==================================================
# downloaded 307 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/ddalpha_1.3.1.tar.gz'
# Content type 'application/x-gzip' length 543340 bytes (530 KB)
# ==================================================
# downloaded 530 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/gower_0.1.2.tar.gz'
# Content type 'application/x-gzip' length 17393 bytes (16 KB)
# ==================================================
# downloaded 16 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/RcppRoll_0.2.2.tar.gz'
# Content type 'application/x-gzip' length 13680 bytes (13 KB)
# ==================================================
# downloaded 13 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/tidyselect_0.2.3.tar.gz'
# Content type 'application/x-gzip' length 21704 bytes (21 KB)
# ==================================================
# downloaded 21 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/checkmate_1.8.5.tar.gz'
# Content type 'application/x-gzip' length 182266 bytes (177 KB)
# ==================================================
# downloaded 177 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/zoo_1.8-0.tar.gz'
# Content type 'application/x-gzip' length 839729 bytes (820 KB)
# ==================================================
# downloaded 820 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/pbivnorm_0.6.0.tar.gz'
# Content type 'application/x-gzip' length 8594 bytes
# ==================================================
# downloaded 8594 bytes
#
# trying URL 'http://cran.us.r-project.org/src/contrib/quadprog_1.5-5.tar.gz'
# Content type 'application/x-gzip' length 33651 bytes (32 KB)
# ==================================================
# downloaded 32 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/numDeriv_2016.8-1.tar.gz'
# Content type 'application/x-gzip' length 76303 bytes (74 KB)
# ==================================================
# downloaded 74 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/matrixcalc_1.0-3.tar.gz'
# Content type 'application/x-gzip' length 28499 bytes (27 KB)
# ==================================================
# downloaded 27 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/mi_1.0.tar.gz'
# Content type 'application/x-gzip' length 793313 bytes (774 KB)
# ==================================================
# downloaded 774 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/minqa_1.2.4.tar.gz'
# Content type 'application/x-gzip' length 53548 bytes (52 KB)
# ==================================================
# downloaded 52 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/nloptr_1.0.4.tar.gz'
# Content type 'application/x-gzip' length 353957 bytes (345 KB)
# ==================================================
# downloaded 345 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/RcppEigen_0.3.3.3.1.tar.gz'
# Content type 'application/x-gzip' length 1627022 bytes (1.6 MB)
# ==================================================
# downloaded 1.6 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/R.methodsS3_1.7.1.tar.gz'
# Content type 'application/x-gzip' length 25731 bytes (25 KB)
# ==================================================
# downloaded 25 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/R.oo_1.21.0.tar.gz'
# Content type 'application/x-gzip' length 403410 bytes (393 KB)
# ==================================================
# downloaded 393 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/R.utils_2.6.0.tar.gz'
# Content type 'application/x-gzip' length 393884 bytes (384 KB)
# ==================================================
# downloaded 384 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/R.cache_0.12.0.tar.gz'
# Content type 'application/x-gzip' length 31694 bytes (30 KB)
# ==================================================
# downloaded 30 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/bindrcpp_0.2.tar.gz'
# Content type 'application/x-gzip' length 8089 bytes
# ==================================================
# downloaded 8089 bytes
#
# trying URL 'http://cran.us.r-project.org/src/contrib/glue_1.2.0.tar.gz'
# Content type 'application/x-gzip' length 28193 bytes (27 KB)
# ==================================================
# downloaded 27 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/rlang_0.1.4.tar.gz'
# Content type 'application/x-gzip' length 201334 bytes (196 KB)
# ==================================================
# downloaded 196 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/plogr_0.1-1.tar.gz'
# Content type 'application/x-gzip' length 7421 bytes
# ==================================================
# downloaded 7421 bytes
#
# trying URL 'http://cran.us.r-project.org/src/contrib/hms_0.4.0.tar.gz'
# Content type 'application/x-gzip' length 12506 bytes (12 KB)
# ==================================================
# downloaded 12 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/dichromat_2.0-0.tar.gz'
# Content type 'application/x-gzip' length 84320 bytes (82 KB)
# ==================================================
# downloaded 82 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/munsell_0.4.3.tar.gz'
# Content type 'application/x-gzip' length 97244 bytes (94 KB)
# ==================================================
# downloaded 94 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/labeling_0.3.tar.gz'
# Content type 'application/x-gzip' length 10722 bytes (10 KB)
# ==================================================
# downloaded 10 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/viridisLite_0.2.0.tar.gz'
# Content type 'application/x-gzip' length 48073 bytes (46 KB)
# ==================================================
# downloaded 46 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/ModelMetrics_1.1.0.tar.gz'
# Content type 'application/x-gzip' length 11615 bytes (11 KB)
# ==================================================
# downloaded 11 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/recipes_0.1.1.tar.gz'
# Content type 'application/x-gzip' length 563731 bytes (550 KB)
# ==================================================
# downloaded 550 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/filehash_2.4-1.tar.gz'
# Content type 'application/x-gzip' length 141497 bytes (138 KB)
# ==================================================
# downloaded 138 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/xtable_1.8-2.tar.gz'
# Content type 'application/x-gzip' length 619611 bytes (605 KB)
# ==================================================
# downloaded 605 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/sourcetools_0.1.6.tar.gz'
# Content type 'application/x-gzip' length 24092 bytes (23 KB)
# ==================================================
# downloaded 23 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/gtools_3.5.0.tar.gz'
# Content type 'application/x-gzip' length 64855 bytes (63 KB)
# ==================================================
# downloaded 63 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/gdata_2.18.0.tar.gz'
# Content type 'application/x-gzip' length 1058430 bytes (1.0 MB)
# ==================================================
# downloaded 1.0 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/caTools_1.17.1.tar.gz'
# Content type 'application/x-gzip' length 63358 bytes (61 KB)
# ==================================================
# downloaded 61 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/Formula_1.2-2.tar.gz'
# Content type 'application/x-gzip' length 150946 bytes (147 KB)
# ==================================================
# downloaded 147 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/latticeExtra_0.6-28.tar.gz'
# Content type 'application/x-gzip' length 1294369 bytes (1.2 MB)
# ==================================================
# downloaded 1.2 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/acepack_1.4.1.tar.gz'
# Content type 'application/x-gzip' length 34848 bytes (34 KB)
# ==================================================
# downloaded 34 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/data.table_1.10.4-3.tar.gz'
# Content type 'application/x-gzip' length 3071833 bytes (2.9 MB)
# ==================================================
# downloaded 2.9 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/htmlTable_1.9.tar.gz'
# Content type 'application/x-gzip' length 152095 bytes (148 KB)
# ==================================================
# downloaded 148 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/viridis_0.4.0.tar.gz'
# Content type 'application/x-gzip' length 1787731 bytes (1.7 MB)
# ==================================================
# downloaded 1.7 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/mvtnorm_1.0-6.tar.gz'
# Content type 'application/x-gzip' length 159232 bytes (155 KB)
# ==================================================
# downloaded 155 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/TH.data_1.0-8.tar.gz'
# Content type 'application/x-gzip' length 4963504 bytes (4.7 MB)
# ==================================================
# downloaded 4.7 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/sandwich_2.4-0.tar.gz'
# Content type 'application/x-gzip' length 1280592 bytes (1.2 MB)
# ==================================================
# downloaded 1.2 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/SparseM_1.77.tar.gz'
# Content type 'application/x-gzip' length 756317 bytes (738 KB)
# ==================================================
# downloaded 738 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/MatrixModels_0.4-1.tar.gz'
# Content type 'application/x-gzip' length 23065 bytes (22 KB)
# ==================================================
# downloaded 22 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/gdtools_0.1.6.tar.gz'
# Content type 'application/x-gzip' length 35263 bytes (34 KB)
# ==================================================
# downloaded 34 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/mnormt_1.5-5.tar.gz'
# Content type 'application/x-gzip' length 37169 bytes (36 KB)
# ==================================================
# downloaded 36 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/GPArotation_2014.11-1.tar.gz'
# Content type 'application/x-gzip' length 95378 bytes (93 KB)
# ==================================================
# downloaded 93 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/lavaan_0.5-23.1097.tar.gz'
# Content type 'application/x-gzip' length 453823 bytes (443 KB)
# ==================================================
# downloaded 443 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/sem_3.1-9.tar.gz'
# Content type 'application/x-gzip' length 155278 bytes (151 KB)
# ==================================================
# downloaded 151 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/lme4_1.1-14.tar.gz'
# Content type 'application/x-gzip' length 3601039 bytes (3.4 MB)
# ==================================================
# downloaded 3.4 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/Rcsdp_0.1.55.tar.gz'
# Content type 'application/x-gzip' length 490001 bytes (478 KB)
# ==================================================
# downloaded 478 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/plyr_1.8.4.tar.gz'
# Content type 'application/x-gzip' length 392451 bytes (383 KB)
# ==================================================
# downloaded 383 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/R.rsp_0.41.0.tar.gz'
# Content type 'application/x-gzip' length 854152 bytes (834 KB)
# ==================================================
# downloaded 834 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/sp_1.2-5.tar.gz'
# Content type 'application/x-gzip' length 1134121 bytes (1.1 MB)
# ==================================================
# downloaded 1.1 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/DBI_0.7.tar.gz'
# Content type 'application/x-gzip' length 613174 bytes (598 KB)
# ==================================================
# downloaded 598 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/dplyr_0.7.4.tar.gz'
# Content type 'application/x-gzip' length 808054 bytes (789 KB)
# ==================================================
# downloaded 789 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/dbplyr_1.1.0.tar.gz'
# Content type 'application/x-gzip' length 247062 bytes (241 KB)
# ==================================================
# downloaded 241 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/readr_1.1.1.tar.gz'
# Content type 'application/x-gzip' length 233793 bytes (228 KB)
# ==================================================
# downloaded 228 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/purrr_0.2.4.tar.gz'
# Content type 'application/x-gzip' length 126147 bytes (123 KB)
# ==================================================
# downloaded 123 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/scales_0.5.0.tar.gz'
# Content type 'application/x-gzip' length 59867 bytes (58 KB)
# ==================================================
# downloaded 58 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/RJDBC_0.2-5.tar.gz'
# Content type 'application/x-gzip' length 13879 bytes (13 KB)
# ==================================================
# downloaded 13 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/rJava_0.9-9.tar.gz'
# Content type 'application/x-gzip' length 660454 bytes (644 KB)
# ==================================================
# downloaded 644 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/RColorBrewer_1.1-2.tar.gz'
# Content type 'application/x-gzip' length 11532 bytes (11 KB)
# ==================================================
# downloaded 11 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/RUnit_0.4.31.tar.gz'
# Content type 'application/x-gzip' length 324003 bytes (316 KB)
# ==================================================
# downloaded 316 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/caret_6.0-77.tar.gz'
# Content type 'application/x-gzip' length 4668444 bytes (4.5 MB)
# ==================================================
# downloaded 4.5 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/mlbench_2.1-1.tar.gz'
# Content type 'application/x-gzip' length 920768 bytes (899 KB)
# ==================================================
# downloaded 899 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/formatR_1.5.tar.gz'
# Content type 'application/x-gzip' length 103853 bytes (101 KB)
# ==================================================
# downloaded 101 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/testit_0.7.tar.gz'
# Content type 'application/x-gzip' length 9149 bytes
# ==================================================
# downloaded 9149 bytes
#
# trying URL 'http://cran.us.r-project.org/src/contrib/rgl_0.98.1.tar.gz'
# Content type 'application/x-gzip' length 2624282 bytes (2.5 MB)
# ==================================================
# downloaded 2.5 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/htmlwidgets_0.9.tar.gz'
# Content type 'application/x-gzip' length 944851 bytes (922 KB)
# ==================================================
# downloaded 922 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/webshot_0.4.2.tar.gz'
# Content type 'application/x-gzip' length 1378726 bytes (1.3 MB)
# ==================================================
# downloaded 1.3 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/tikzDevice_0.10-1.tar.gz'
# Content type 'application/x-gzip' length 1442979 bytes (1.4 MB)
# ==================================================
# downloaded 1.4 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/png_0.1-7.tar.gz'
# Content type 'application/x-gzip' length 24990 bytes (24 KB)
# ==================================================
# downloaded 24 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/jpeg_0.1-8.tar.gz'
# Content type 'application/x-gzip' length 18046 bytes (17 KB)
# ==================================================
# downloaded 17 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/XML_3.98-1.9.tar.gz'
# Content type 'application/x-gzip' length 1599437 bytes (1.5 MB)
# ==================================================
# downloaded 1.5 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/RCurl_1.95-4.8.tar.gz'
# Content type 'application/x-gzip' length 916934 bytes (895 KB)
# ==================================================
# downloaded 895 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/tibble_1.3.4.tar.gz'
# Content type 'application/x-gzip' length 93163 bytes (90 KB)
# ==================================================
# downloaded 90 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/shiny_1.0.5.tar.gz'
# Content type 'application/x-gzip' length 2330710 bytes (2.2 MB)
# ==================================================
# downloaded 2.2 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/tufte_0.2.tar.gz'
# Content type 'application/x-gzip' length 241740 bytes (236 KB)
# ==================================================
# downloaded 236 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/gplots_3.0.1.tar.gz'
# Content type 'application/x-gzip' length 578626 bytes (565 KB)
# ==================================================
# downloaded 565 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/gtable_0.2.0.tar.gz'
# Content type 'application/x-gzip' length 24157 bytes (23 KB)
# ==================================================
# downloaded 23 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/egg_0.2.0.tar.gz'
# Content type 'application/x-gzip' length 1415030 bytes (1.3 MB)
# ==================================================
# downloaded 1.3 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/reshape2_1.4.2.tar.gz'
# Content type 'application/x-gzip' length 34688 bytes (33 KB)
# ==================================================
# downloaded 33 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/ggplot2movies_0.0.1.tar.gz'
# Content type 'application/x-gzip' length 907405 bytes (886 KB)
# ==================================================
# downloaded 886 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/hexbin_1.27.1.tar.gz'
# Content type 'application/x-gzip' length 550360 bytes (537 KB)
# ==================================================
# downloaded 537 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/Hmisc_4.0-3.tar.gz'
# Content type 'application/x-gzip' length 702759 bytes (686 KB)
# ==================================================
# downloaded 686 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/mapproj_1.2-5.tar.gz'
# Content type 'application/x-gzip' length 25690 bytes (25 KB)
# ==================================================
# downloaded 25 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/maps_3.2.0.tar.gz'
# Content type 'application/x-gzip' length 2343919 bytes (2.2 MB)
# ==================================================
# downloaded 2.2 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/maptools_0.9-2.tar.gz'
# Content type 'application/x-gzip' length 1586102 bytes (1.5 MB)
# ==================================================
# downloaded 1.5 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/multcomp_1.4-8.tar.gz'
# Content type 'application/x-gzip' length 607674 bytes (593 KB)
# ==================================================
# downloaded 593 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/quantreg_5.34.tar.gz'
# Content type 'application/x-gzip' length 1640231 bytes (1.6 MB)
# ==================================================
# downloaded 1.6 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/svglite_1.2.1.tar.gz'
# Content type 'application/x-gzip' length 41315 bytes (40 KB)
# ==================================================
# downloaded 40 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/psych_1.7.8.tar.gz'
# Content type 'application/x-gzip' length 3311758 bytes (3.2 MB)
# ==================================================
# downloaded 3.2 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/jsonlite_1.5.tar.gz'
# Content type 'application/x-gzip' length 1096810 bytes (1.0 MB)
# ==================================================
# downloaded 1.0 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/sergeant_0.5.2.tar.gz'
# Content type 'application/x-gzip' length 29523 bytes (28 KB)
# ==================================================
# downloaded 28 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/randomForest_4.6-12.tar.gz'
# Content type 'application/x-gzip' length 79566 bytes (77 KB)
# ==================================================
# downloaded 77 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/foreach_1.4.3.tar.gz'
# Content type 'application/x-gzip' length 359787 bytes (351 KB)
# ==================================================
# downloaded 351 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/iterators_1.0.8.tar.gz'
# Content type 'application/x-gzip' length 290412 bytes (283 KB)
# ==================================================
# downloaded 283 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/doParallel_1.0.11.tar.gz'
# Content type 'application/x-gzip' length 172885 bytes (168 KB)
# ==================================================
# downloaded 168 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/knitr_1.17.tar.gz'
# Content type 'application/x-gzip' length 769923 bytes (751 KB)
# ==================================================
# downloaded 751 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/rmarkdown_1.8.tar.gz'
# Content type 'application/x-gzip' length 2093181 bytes (2.0 MB)
# ==================================================
# downloaded 2.0 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/ROCR_1.0-7.tar.gz'
# Content type 'application/x-gzip' length 107872 bytes (105 KB)
# ==================================================
# downloaded 105 KB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/gridExtra_2.3.tar.gz'
# Content type 'application/x-gzip' length 1062844 bytes (1.0 MB)
# ==================================================
# downloaded 1.0 MB
#
# trying URL 'http://cran.us.r-project.org/src/contrib/ggplot2_2.2.1.tar.gz'
# Content type 'application/x-gzip' length 2213308 bytes (2.1 MB)
# ==================================================
# downloaded 2.1 MB
#
# * installing *source* package ‘kernlab’ ...
# ** package ‘kernlab’ successfully unpacked and MD5 sums checked
# ** libs
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c brweight.cpp -o brweight.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c ctable.cpp -o ctable.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c cweight.cpp -o cweight.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dbreakpt.c -o dbreakpt.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dcauchy.c -o dcauchy.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dgpnrm.c -o dgpnrm.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dgpstep.c -o dgpstep.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dprecond.c -o dprecond.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dprsrch.c -o dprsrch.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dspcg.c -o dspcg.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dtron.c -o dtron.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dtrpcg.c -o dtrpcg.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c dtrqsol.c -o dtrqsol.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c esa.cpp -o esa.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c expdecayweight.cpp -o expdecayweight.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c inductionsort.cpp -o inductionsort.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c kspectrumweight.cpp -o kspectrumweight.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c lcp.cpp -o lcp.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c misc.c -o misc.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c msufsort.cpp -o msufsort.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c solvebqp.c -o solvebqp.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c stringk.c -o stringk.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c stringkernel.cpp -o stringkernel.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c svm.cpp -o svm.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c wkasailcp.cpp -o wkasailcp.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c wmsufsort.cpp -o wmsufsort.o
# g++ -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o kernlab.so brweight.o ctable.o cweight.o dbreakpt.o dcauchy.o dgpnrm.o dgpstep.o dprecond.o dprsrch.o dspcg.o dtron.o dtrpcg.o dtrqsol.o esa.o expdecayweight.o inductionsort.o kspectrumweight.o lcp.o misc.o msufsort.o solvebqp.o stringk.o stringkernel.o svm.o wkasailcp.o wmsufsort.o -llapack -lblas -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/kernlab/libs
# ** R
# ** data
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (kernlab)
# * installing *source* package ‘DEoptimR’ ...
# ** package ‘DEoptimR’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (DEoptimR)
# * installing *source* package ‘abind’ ...
# ** package ‘abind’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (abind)
# * installing *source* package ‘coda’ ...
# ** package ‘coda’ successfully unpacked and MD5 sums checked
# ** R
# ** data
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (coda)
# * installing *source* package ‘sfsmisc’ ...
# ** package ‘sfsmisc’ successfully unpacked and MD5 sums checked
# ** R
# ** data
# ** demo
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (sfsmisc)
# * installing *source* package ‘bindr’ ...
# ** package ‘bindr’ successfully unpacked and MD5 sums checked
# ** R
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (bindr)
# * installing *source* package ‘colorspace’ ...
# ** package ‘colorspace’ successfully unpacked and MD5 sums checked
# ** libs
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c colorspace.c -o colorspace.o
# gcc -std=gnu99 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o colorspace.so colorspace.o -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/colorspace/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (colorspace)
# * installing *source* package ‘lubridate’ ...
# ** package ‘lubridate’ successfully unpacked and MD5 sums checked
# ** libs
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c RcppExports.cpp -o RcppExports.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c datetime.c -o datetime.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c period.c -o period.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c tparse.c -o tparse.o
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c update.cpp -o update.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c utils.c -o utils.o
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c cctz/src/time_zone_fixed.cc -o cctz/src/time_zone_fixed.o
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c cctz/src/time_zone_if.cc -o cctz/src/time_zone_if.o
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c cctz/src/time_zone_impl.cc -o cctz/src/time_zone_impl.o
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c cctz/src/time_zone_info.cc -o cctz/src/time_zone_info.o
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c cctz/src/time_zone_libc.cc -o cctz/src/time_zone_libc.o
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c cctz/src/time_zone_lookup.cc -o cctz/src/time_zone_lookup.o
# g++ -std=gnu++11 -I/usr/share/R/include -DNDEBUG -I. -I./cctz/include/ -I./cctz/src/ -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g -c cctz/src/time_zone_posix.cc -o cctz/src/time_zone_posix.o
# ar rcs libcctz.a ./cctz/src/time_zone_fixed.o ./cctz/src/time_zone_if.o ./cctz/src/time_zone_impl.o ./cctz/src/time_zone_info.o ./cctz/src/time_zone_libc.o ./cctz/src/time_zone_lookup.o ./cctz/src/time_zone_posix.o
# g++ -std=gnu++11 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o lubridate.so RcppExports.o datetime.o period.o tparse.o update.o utils.o -L. -lcctz -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/lubridate/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (lubridate)
# * installing *source* package ‘timeDate’ ...
# ** package ‘timeDate’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# Creating a generic function for ‘sample’ from package ‘base’ in package ‘timeDate’
# Creating a generic function for ‘getDataPart’ from package ‘methods’ in package ‘timeDate’
# Creating a generic function for ‘abline’ from package ‘graphics’ in package ‘timeDate’
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (timeDate)
# * installing *source* package ‘gower’ ...
# ** package ‘gower’ successfully unpacked and MD5 sums checked
# ** libs
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG     -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c R_register_native.c -o R_register_native.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG     -fopenmp -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c gower.c -o gower.o
# gcc -std=gnu99 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o gower.so R_register_native.o gower.o -fopenmp -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/gower/libs
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (gower)
# * installing *source* package ‘RcppRoll’ ...
# ** package ‘RcppRoll’ successfully unpacked and MD5 sums checked
# ** libs
# g++  -I/usr/share/R/include -DNDEBUG  -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c RcppExports.cpp -o RcppExports.o
# g++  -I/usr/share/R/include -DNDEBUG  -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c rollit.cpp -o rollit.o
# g++ -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o RcppRoll.so RcppExports.o rollit.o -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/RcppRoll/libs
# ** R
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (RcppRoll)
# ...
# g++ -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o scales.so RcppExports.o colors.o -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/scales/libs
# ** R
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (scales)
# * installing *source* package ‘rgl’ ...
# ** package ‘rgl’ successfully unpacked and MD5 sums checked
# checking for gcc... gcc -std=gnu99
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc -std=gnu99 accepts -g... yes
# checking for gcc -std=gnu99 option to accept ISO C89... none needed
# checking how to run the C preprocessor... gcc -std=gnu99 -E
# checking for gcc... (cached) gcc -std=gnu99
# checking whether we are using the GNU C compiler... (cached) yes
# checking whether gcc -std=gnu99 accepts -g... (cached) yes
# checking for gcc -std=gnu99 option to accept ISO C89... (cached) none needed
# checking for libpng-config... yes
# configure: using libpng-config
# configure: using libpng dynamic linkage
# checking for X... no
# configure: error: X11 not found but required, configure aborted.
# ERROR: configuration failed for package ‘rgl’
# * removing ‘/usr/local/lib/R/site-library/rgl’
# * installing *source* package ‘tufte’ ...
# ** package ‘tufte’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (tufte)
# * installing *source* package ‘gplots’ ...
# ** package ‘gplots’ successfully unpacked and MD5 sums checked
# ** R
# ** data
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (gplots)
# * installing *source* package ‘multcomp’ ...
# ** package ‘multcomp’ successfully unpacked and MD5 sums checked
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** demo
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (multcomp)
# * installing *source* package ‘doParallel’ ...
# ** package ‘doParallel’ successfully unpacked and MD5 sums checked
# ** R
# ** demo
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (doParallel)
# * installing *source* package ‘ipred’ ...
# ** package ‘ipred’ successfully unpacked and MD5 sums checked
# ** libs
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c SdiffKM.c -o SdiffKM.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c init.c -o init.o
# gcc -std=gnu99 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o ipred.so SdiffKM.o init.o -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/ipred/libs
# ** R
# ** data
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (ipred)
# * installing *source* package ‘dimRed’ ...
# ** package ‘dimRed’ successfully unpacked and MD5 sums checked
# ** R
# ** preparing package for lazy loading
# Creating a new generic function for ‘as.data.frame’ in package ‘dimRed’
# Creating a generic function for ‘nrow’ from package ‘base’ in package ‘dimRed’
# Creating a new generic function for ‘embed’ in package ‘dimRed’
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (dimRed)
# * installing *source* package ‘tidyselect’ ...
# ** package ‘tidyselect’ successfully unpacked and MD5 sums checked
# ** libs
# g++  -I/usr/share/R/include -DNDEBUG  -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c RcppExports.cpp -o RcppExports.o
# g++  -I/usr/share/R/include -DNDEBUG  -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c combine_variables.cpp -o combine_variables.o
# g++ -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o tidyselect.so RcppExports.o combine_variables.o -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/tidyselect/libs
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (tidyselect)
# * installing *source* package ‘mi’ ...
# ** package ‘mi’ successfully unpacked and MD5 sums checked
# ** R
# ** data
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (mi)
# * installing *source* package ‘R.cache’ ...
# ** package ‘R.cache’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (R.cache)
# * installing *source* package ‘dbplyr’ ...
# ** package ‘dbplyr’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (dbplyr)
# * installing *source* package ‘ROCR’ ...
# ** package ‘ROCR’ successfully unpacked and MD5 sums checked
# ** R
# ** data
# ** demo
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (ROCR)
# * installing *source* package ‘ggplot2’ ...
# ** package ‘ggplot2’ successfully unpacked and MD5 sums checked
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (ggplot2)
# * installing *source* package ‘tidyr’ ...
# ** package ‘tidyr’ successfully unpacked and MD5 sums checked
# ** libs
# g++  -I/usr/share/R/include -DNDEBUG  -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c RcppExports.cpp -o RcppExports.o
# g++  -I/usr/share/R/include -DNDEBUG  -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c fill.cpp -o fill.o
# g++  -I/usr/share/R/include -DNDEBUG  -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c melt.cpp -o melt.o
# g++  -I/usr/share/R/include -DNDEBUG  -I"/usr/local/lib/R/site-library/Rcpp/include"    -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c simplifyPieces.cpp -o simplifyPieces.o
# g++ -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o tidyr.so RcppExports.o fill.o melt.o simplifyPieces.o -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/tidyr/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** demo
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (tidyr)
# * installing *source* package ‘viridis’ ...
# ** package ‘viridis’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (viridis)
# * installing *source* package ‘sem’ ...
# ** package ‘sem’ successfully unpacked and MD5 sums checked
# ** libs
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c csemnlm.c -o csemnlm.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c uncmin.c -o uncmin.o
# g++  -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c csem.cpp -o csem.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c init.c -o init.o
# g++ -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o sem.so csemnlm.o uncmin.o csem.o init.o -lm -llapack -lblas -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/sem/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (sem)
# * installing *source* package ‘R.rsp’ ...
# ** package ‘R.rsp’ successfully unpacked and MD5 sums checked
# ** R
# ** exec
# ** inst
# ** preparing package for lazy loading
# Warning in setGenericS3.default(name, export = exportGeneric, envir = envir,  :
#   Renamed the preexisting function write to write.default, which was defined in environment base.
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (R.rsp)
# * installing *source* package ‘egg’ ...
# ** package ‘egg’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (egg)
# * installing *source* package ‘sergeant’ ...
# ** package ‘sergeant’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (sergeant)
# * installing *source* package ‘broom’ ...
# ** package ‘broom’ successfully unpacked and MD5 sums checked
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (broom)
# * installing *source* package ‘Hmisc’ ...
# ** package ‘Hmisc’ successfully unpacked and MD5 sums checked
# ** libs
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c Hmisc.c -o Hmisc.o
# gfortran   -fpic  -g -O2 -fstack-protector-strong  -c cidxcn.f -o cidxcn.o
# gfortran   -fpic  -g -O2 -fstack-protector-strong  -c cidxcp.f -o cidxcp.o
# gfortran   -fpic  -g -O2 -fstack-protector-strong  -c hoeffd.f -o hoeffd.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c init.c -o init.o
# gfortran   -fpic  -g -O2 -fstack-protector-strong  -c jacklins.f -o jacklins.o
# gfortran   -fpic  -g -O2 -fstack-protector-strong  -c largrec.f -o largrec.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c mChoice.c -o mChoice.o
# gfortran   -fpic  -g -O2 -fstack-protector-strong  -c maxempr.f -o maxempr.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c nstr.c -o nstr.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c ranksort.c -o ranksort.o
# gfortran   -fpic  -g -O2 -fstack-protector-strong  -c rcorr.f -o rcorr.o
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c string_box.c -o string_box.o
# gfortran   -fpic  -g -O2 -fstack-protector-strong  -c wclosest.f -o wclosest.o
# gcc -std=gnu99 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o Hmisc.so Hmisc.o cidxcn.o cidxcp.o hoeffd.o init.o jacklins.o largrec.o mChoice.o maxempr.o nstr.o ranksort.o rcorr.o string_box.o wclosest.o -lgfortran -lm -lquadmath -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/Hmisc/libs
# ** R
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (Hmisc)
# * installing *source* package ‘recipes’ ...
# ** package ‘recipes’ successfully unpacked and MD5 sums checked
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (recipes)
# * installing *source* package ‘caret’ ...
# ** package ‘caret’ successfully unpacked and MD5 sums checked
# ** libs
# gcc -std=gnu99 -I/usr/share/R/include -DNDEBUG      -fpic  -g -O2 -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c caret.c -o caret.o
# gcc -std=gnu99 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o caret.so caret.o -L/usr/lib/R/lib -lR
# installing to /usr/local/lib/R/site-library/caret/libs
# ** R
# ** data
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (caret)
#
# The downloaded source packages are in
# 	‘/tmp/RtmppB3mTJ/downloaded_packages’
# Warning messages:
# 1: packages ‘parallel’, ‘stats’ are not available (for R version 3.4.2)
# 2: packages ‘parallel’, ‘stats’ are base packages, and should not be updated
# 3: In install.packages(c("psych", "jsonlite", "sergeant", "randomForest",  :
#   installation of package ‘gdtools’ had non-zero exit status
# 4: In install.packages(c("psych", "jsonlite", "sergeant", "randomForest",  :
#   installation of package ‘svglite’ had non-zero exit status
# 5: In install.packages(c("psych", "jsonlite", "sergeant", "randomForest",  :
#   installation of package ‘rgl’ had non-zero exit status
#  ---> 71f50205893f
# Removing intermediate container 17a857eef7cf
# Step 9/11 : RUN R CMD INSTALL /code/returnsModel_2.1-6.tar.gz
#  ---> Running in 4b221edd531d
# * installing to library ‘/usr/local/lib/R/site-library’
# * installing *source* package ‘returnsModel’ ...
# ** R
# ** data
# ** inst
# ** preparing package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded
# * DONE (returnsModel)
#  ---> 68f0eb221dc1
# Removing intermediate container 4b221edd531d
# Step 10/11 : EXPOSE 8080
#  ---> Running in 9581c1e79d1a
#  ---> 058c9ff749c9
# Removing intermediate container 9581c1e79d1a
# Step 11/11 : CMD supervisord -c /etc/supervisord.conf
#  ---> Running in 04380e8a3e26
#  ---> e9a28d41c4e0
# Removing intermediate container 04380e8a3e26
# Successfully built e9a28d41c4e0

# %% [raw]
# !docker run -it -e MAPR_CLUSTER=maprlab -e MAPR_CLDB_HOSTS=mapr-1,mapr-2,mapr-3 -e MAPR_CONTAINER_USER=mapr -e MAPR_CONTAINER_UID=5000 -e MAPR_CONTAINER_GID=5000 -e MAPR_MOUNT_POINT=/mapr --device /dev/fuse --security-opt apparmor:unconfined --name score -p 6060:8080 $image_name

# %%
# !docker ps -a
# Out:
# CONTAINER ID        IMAGE               COMMAND                  CREATED             STATUS                     PORTS               NAMES
# f687d46c112d        thbeh/test          "/opt/mapr/install..."   4 minutes ago       Exited (0) 5 seconds ago                       score

# %%
# !docker rmi 0dbdaaafb97c
# Out:
# Deleted: sha256:0dbdaaafb97cfd2347d7ea792bc75ec14efbfa6994baa71d671b726ec4f3f034
# Deleted: sha256:aa0ebefcb4ba7d8c8efea6e9a5da852cc05f927b606649c6e64aa797c3849eb1
# Deleted: sha256:ef510ba0f80c2fcf7db635528b2edacf6646d5540fd6d62d07968ff90328f06e
# Deleted: sha256:d7050fd3e87eade8ad3051b5a910145fa97baabe574c1486437d471b444cfc54
# Deleted: sha256:35c44dc6eacd611c412786c9b319c82dc779fd8616e769fd2c759ac09213ae6c
# Deleted: sha256:4499cc5cea262e03b6ffa8ccb948c4398d258c8176eec84734a88c4d69afbafb
# Deleted: sha256:8d7db60bf1198940faae1e8c193518cc7bf971a63b70f63296dcd87514374d01
# Deleted: sha256:8ec04630f111f16df53e32a0d2e21d19972c51e233df72d845720f0cf2f637d5
# Deleted: sha256:abf39fd24dc3324cf0dd3a0363bec75f77d787c4d9f405c0e8e766e487543f32
# Deleted: sha256:c644ae04a78eec19b227b03c24959fb9ca18af07c8a4a0f3d75f7ee310671882
# Deleted: sha256:b34207502e7f4af737b373d06e61d8c6f70a3788142f308a768130ba7436dbd8
# Deleted: sha256:a41925a6e229204b61c0c42d76122c18aed9f7402f7690f32322f89574d732a2

# %%
# !docker rm score
# Out:
# score

# %%
# !docker rmi thbeh/test
# Out:
# Untagged: thbeh/test:latest
# Deleted: sha256:c546cbbe4661e5e3dc644d31d9542ebe28f1ad7ef76a5774e0c59c9e4bf3b122
# Deleted: sha256:1cbf79f2ff06ff0dc96dabd129975574d3014edca974bfb95ce737269a837cc2
# Deleted: sha256:6c9dbca51ff640619935f8046b8023e97e04a797b7f9ffdb858f26cfd1bdc139
# Deleted: sha256:95cc36ca5b287607958ceda066a0289de4781bf2316df22d7008d05fe676e0b0
# Deleted: sha256:032400d7c263d86aef5aeba451a85dabe8cca5565c5d69f1b678529b49afef13
# Deleted: sha256:042b009de35ba5050a3bb8063ebcda5d90652fd85e017a509764660d0a3ac14e
# Deleted: sha256:0cb47792332d68f24937d0c3b3041aa4e8db33094bf5eb2cea0f7edf8a9f2cd6
# Deleted: sha256:e9e0c394e71cd691fca49ea0034251c7c6d3593ad61ed1c9f8ffe9aed76144df
# Deleted: sha256:fbc9671fe5291c769928aa7e45032e2d5821a695191f8ab457e6f20c0073e1d1
# Deleted: sha256:c2b3ffcc557c81e5dd9bf354959a676ba4fd239dcd862a00f07de538a9b546c6
# Deleted: sha256:eb1406ab60cce06b126c9f797d24b4d9c029acb8af5fabac244cc0f92d1354c5
# Deleted: sha256:127cb856134a9691d692b5dd7eee298988e0e1b65aa3cc81d572c63716b7ffca
# Deleted: sha256:9e38cf4fc4dacf76a6910d4aec2db0164412bd8bb47757a6961e439bcc820a61
# Deleted: sha256:eb01b5d5d89352527a9d6ba943bea8ad14e143b88aeb243f39c4c6ab25d98a19
# Deleted: sha256:11390fc2f673957a92554dda626f7003e037f41e0c5d9521fde2955001de0310
# Deleted: sha256:cf077cd1f356c039830188f3be2b49dabdf08b9aa097b8564d72e1e82e16a03d
# Deleted: sha256:c3e2e68d746f0d01cf9e36ce897a2d5706e2fb7aba8e8aa96505fc5577ef6237
# Deleted: sha256:51bdbfa494402e652664565791a1efd08e4f7b3b854f50eec8b528da6813213e
