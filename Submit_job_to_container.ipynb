# %% [markdown]
# Refresh the model

# %%
# !curl --data "model='OR', returnName='IR6', projectStage='TEST', nrows=1000" http://localhost:6002/domodelling
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.
# ["/code/OR_IR6_2017-11-29_modelling.RData"]

# %% [markdown]
# Run the scoring

# %%
# !curl --data "model='OR', returnName='IR6', modelRunDate='2017-11-28', projectStage='TEST', nrows=1000, irdNumbersForScoring=''" http://localhost:6002/doscoring
# Out:
# [{"IRD_NUMBER":91814986,"RETURN_PERIOD_DATE":"2014-03-31","RETURN_TYPE":"IR6","MODEL_ID":1,"RUN_ID":1,"LOCATION_NUMBER":1,"TAX_TYPE":"INC","FILING_FREQUENCY":1,"POPULATION_NO":1,"EST_OTHER_INCOME":0,"PROB_NIL_OTHER_INCOME":1,"EST_RESIDUAL_INCOME_TAX":0,"PROB_NIL_RESIDUAL_INCOME_TAX":1,"PROB_RIT_LESS_200":0.99,"PROB_OTHER_INC_LESS_1000":1,"PROB_NIL_INC_ALLOCN_TO_BNFICIR":1},{"IRD_NUMBER":65638215,"RETURN_PERIOD_DATE":"2015-03-31","RETURN_TYPE":"IR6","MODEL_ID":1,"RUN_ID":1,"LOCATION_NUMBER":1,"TAX_TYPE":"INC","FILING_FREQUENCY":1,"POPULATION_NO":1,"EST_OTHER_INCOME":739.1062,"PROB_NIL_OTHER_INCOME":0.61,"EST_RESIDUAL_INCOME_TAX":493.5094,"PROB_NIL_RESIDUAL_INCOME_TAX":0.6,"PROB_RIT_LESS_200":0.43,"PROB_OTHER_INC_LESS_1000":0.58,"PROB_NIL_INC_ALLOCN_TO_BNFICIR":0.72},{"IRD_NUMBER":95088163,"RETURN_PERIOD_DATE":"2015-03-31","RETURN_TYPE":"IR6","MODEL_ID":1,"RUN_ID":1,"LOCATION_NUMBER":1,"TAX_TYPE":"INC","FILING_FREQUENCY":1,"POPULATION_NO":1,"EST_OTHER_INCOME":153.5648,"PROB_NIL_OTHER_I
# ...
